# %% [markdown]
# <a href="https://colab.research.google.com/github/snasreen001/End-To-End-Toy-Project/blob/main/Toy_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#read csv file and store in variable df
df=pd.read_csv('/content/placement.csv')

# %%
#to get overview of data
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
#gives info about each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
#preprocessing
#all rows but col cgpa onwards
df=df.iloc[:,1:]

# %%
#overview
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
#plot cgpa and iq
#placed-yellow,not placed-blue
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
#separate input
X=df.iloc[:,0:2]
#separate output
y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
#Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 20   6.6  120.0
# 23   4.7   87.0
# 99   6.2  113.0
# 97   6.7  182.0
# 58   8.0   79.0
# ..   ...    ...
# 39   4.6  146.0
# 83   7.5  130.0
# 73   4.9   61.0
# 85   5.8  166.0
# 80   4.9  196.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 32   7.0  139.0
# 18   4.0  100.0
# 68   4.0   75.0
# 50   3.5  233.0
# 46   5.3  114.0
# 4    5.8  142.0
# 37   8.1  149.0
# 44   7.5   61.0
# 25   5.0   91.0
# 13   6.4  116.0

# %%
y_train
# Out:
# 20    1
# 23    0
# 99    1
# 97    1
# 58    1
#      ..
# 39    0
# 83    1
# 73    0
# 85    1
# 80    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 32    1
# 18    0
# 68    0
# 50    0
# 46    0
# 4     0
# 37    1
# 44    1
# 25    0
# 13    1
# Name: placement, dtype: int64

# %%
#scaling-put values in the range[-1,1]
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.52771684, -0.09635734],
#        [-1.22450801, -0.94304754],
#        [ 0.1588274 , -0.27595829],
#        [ 0.6199392 ,  1.49439395],
#        [ 1.8188299 , -1.14830577],
#        [ 1.44994045,  0.10890089],
#        [-0.85561857,  0.10890089],
#        [ 0.43549448, -0.8660757 ],
#        [ 1.91105226,  1.08387749],
#        [ 0.89660629,  1.314793  ],
#        [-0.76339621,  2.57199967],
#        [ 0.89660629, -1.53316495],
#        [ 0.71216156,  0.44244552],
#        [-0.76339621,  0.21153001],
#        [ 1.63438517, -0.25030101],
#        [-1.04006329,  0.69901831],
#        [-1.04006329,  0.80164742],
#        [-1.04006329, -0.09635734],
#        [-1.13228565,  1.16084933],
#        [ 0.06660504, -1.09699121],
#        [ 0.43549448, -2.22591148],
#        [ 0.34327212,  0.44244552],
#        [ 0.98882865,  0.69901831],
#        [-0.02561732,  0.64770375],
#        [ 0.71216156, -0.30161557],
#        [ 1.35771809,  0.87861926],
#        [-0.11783968, -0.45555924],
# ...

# %%
X_test=scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.89444712,  0.36909456],
#        [-1.10804643, -0.47765178],
#        [-1.10804643, -1.02043789],
#        [-1.44179535,  2.40997033],
#        [-0.24029923, -0.17369156],
#        [ 0.0934497 ,  0.43422889],
#        [ 1.62869475,  0.586209  ],
#        [ 1.22819604, -1.32439811],
#        [-0.44054858, -0.67305478],
#        [ 0.49394841, -0.13026867]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 32    1
# 18    0
# 68    0
# 50    0
# 46    0
# 4     0
# 37    1
# 44    1
# 25    0
# 13    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >
